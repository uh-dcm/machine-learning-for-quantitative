# %%
install.packages(
    c("caret", "kernlab", "nnet", "factoextra", "ggplot2", "dbscan", "umap", "arules", "kernelshap", "shapviz")
)

# %%
# !pip install pandas scikit-learn matplotlib statsmodels umap-learn mlxtend shap

# %% [markdown]
# ## Data used for the tasks
#
# We use [FDS3077](https://services.fsd.tuni.fi/catalogue/FSD3077?study_language=en) Cross-national Survey on the Future of the Welfare State 2015 as our dataset.
